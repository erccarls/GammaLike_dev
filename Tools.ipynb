# %%
#------------------------------------------------
# Here we generate models and convolve them with 
# instrumental response functions. 
#------------------------------------------------

import healpy
import pyfits

def GetPSF(E_min,E_max,spectral_index=2.5,PSF='/data/fermi_data_1-8-14/psf_P7REP_SOURCE_BOTH.fits'):
    '''
    #---------------------------------------------------------------------------------------------
    # Spectrally weight the PSF(E) and return the average.
    #---------------------------------------------------------------------------------------------
    '''
    hdu = pyfits.open(PSF)
    
    thetas   = np.array([theta[0] for theta in hdu[2].data])
    energies = np.array([energy[0] for energy in hdu[1].data])
    PSFs     = np.array([psf[2] for psf in hdu[1].data])
    
    E_min_bin = np.argmin(np.abs(energies-E_min))
    E_max_bin = np.argmin(np.abs(energies-E_max))+1
    
    
    weights = energies[E_min_bin:E_max_bin]**-spectral_index
    return thetas, np.average(PSFs[E_min_bin:E_max_bin],weights=weights,axis=0)


def ApplyPSF(hpix, E_min,E_max, PSFFile='P7Clean_Front+Back.fits',sigma=.1,smoothed=False):
    '''
    INCOMPLETE: Normalization off and smoothing below healpix scale explodes. 
    This method takes a healpix input 'hpix', and a spectrally averaged energy 'E'. It then looks up the corresponding PSF from tables -> calculates the legendre transform coefficients -> transforms the input pixles into spherical harmonics -> re-weight the alm coefficients according to the PSF -> returns the inverse transform
    '''

    # Spherical Harmonic transform 
    alm  = healpy.sphtfunc.map2alm(hpix)
    
    # get maximum value of l 
    l_max = healpy.sphtfunc.Alm.getlmax(len(alm))
    x = np.linspace(-30,30,10000) # Cos(0) to Cos(pi)
    psf_y = (sigma*np.sqrt(2*np.pi))*np.exp(-x*x/(2*sigma**2))
    psf_x = np.cos(np.deg2rad(x))
    
    # Fit the PSF to l_max legendre polynomials
    cls = np.sqrt(4*np.pi/(2*np.arange(0,l_max+1)+1))*np.polynomial.legendre.legfit(psf_x,psf_y,l_max)
    conv_alm=healpy.sphtfunc.almxfl(alm,cls,)

    # Find nside and return inverse transformed map. 
    nside = healpy.get_nside(hpix)
    if smoothed==False:
        return healpy.sphtfunc.alm2map(conv_alm,nside=nside,)
    else:
        return healpy.sphtfunc.alm2map(alm,nside=nside,sigma=np.deg2rad(sigma))
      

def ApplyGaussianPSF(hpix, E_min,E_max):  
    theta, psf = GetPSF(E_min,E_max)
    
    halfmax = np.argmin(np.abs(0.5-psf/psf.max()))
    FWHM = np.deg2rad(2*theta[halfmax])
    print np.rad2deg(FWHM)
    
    # Spherical Harmonic transform 
    alm  = healpy.sphtfunc.map2alm(hpix)
    # inverse transform with gaussian blur
    return healpy.sphtfunc.alm2map(alm,nside=healpy.get_nside(hpix),fwhm=FWHM)

# %%
#----------------------------------------------------------------------------
# Testing for ApplyPSF
#----------------------------------------------------------------------------
nside = 256
hpix_im = np.zeros(12*nside**2)
hpix_im[ang2hpix(0,0)]=1

# # set center pixel to 1
# hpix_im[ang2hpix(0,0)]=1
# hpix_im = ApplyPSF(hpix_im,100,1000,sigma=1)
# test = healpy.cartview(hpix_im,return_projected_map=True,latra=[-5,5],lonra=[-5,5])
# plt.clf()
# im = plt.imshow(test,extent=[-5,5,-5,5])
# plt.colorbar(im)
# print 'Sum', np.sum(test)

# hpix_im = np.zeros(12*nside**2)
# hpix_im[ang2hpix(0,0)]=1
# hpix_im = ApplyPSF(hpix_im,100,1000,sigma=1,smoothed=True)
# test2 = healpy.cartview(hpix_im,return_projected_map=True,latra=[-5,5],lonra=[-5,5])
# plt.clf()
# im = plt.imshow(test2,extent=[-5,5,-5,5])
# plt.colorbar(im)
# print 'Sum', np.sum(test2)
# plt.show()

# plt.plot(np.linspace(-5,5,800),test[399,:])#/np.max(test))
# plt.plot(np.linspace(-5,5,800),test2[399,:])#/np.max(test2))

#----------------------------------------------------------------------------
# End Testing for ApplyPSF
#----------------------------------------------------------------------------

withPSF = ApplyGaussianPSF(hpix_im,E_min=100,E_max=150)
test2 = healpy.cartview(withPSF,return_projected_map=True,latra=[-5,5],lonra=[-5,5])
im = plt.imshow(test2,extent=[-5,5,-5,5])
# Out:
# 3.2643198967
# Sigma is 83.173742 arcmin (0.024194 rad)
# -> fwhm is 195.859194 arcmin

# %%
x = np.linspace(0,1,2000) # Cos(0) to Cos(pi)
sigma=.3
psf_y = 1/(2.*np.sqrt(np.pi*sigma))*np.exp(-x*x/(2*np.deg2rad(sigma)**2))
fl = np.polynomial.legendre.legfit(np.cos(x),psf_y,767)



plt.plot(np.rad2deg(x),psf_y)

plt.plot(np.rad2deg(x),numpy.polynomial.legendre.legval(np.cos(x), fl))
plt.xlim(-5,5)
# Out:
# (-5, 5)

# %%
healpy.sphtfunc.Alm.getlmax(6)
# Out:
# 2

# %%
# This is distinct for each source class and front/back

    
thetas, psf = GetPSF(100,1000)
plt.plot(thetas,psf)

thetas, psf = GetPSF(500,1000)
plt.plot(thetas,psf)

# %%
hdu = pyfits.open('/home/carlson/fermitools/refdata/fermi/galdiffuse/gll_iem_v05.fits')

print hdu[0].header.cards

energies = np.array([hdu[0].header['CRVAL3']*10**(hdu[0].header['CDELT3']*i) for i in range(hdu[0].header['NAXIS3'])])

dnde     =  np.sum(np.sum(hdu[0].data,axis=1),axis=1)
print list(dnde)


plt.loglog(energies,dnde )

def GetSpectralIndex(E_min, E_max):
    E = np.array([58.473133087158203, 79.970359802246108, 109.37088726489363, 149.58030713742139, 204.57243095354417, 279.7820134691566, 382.64185792772452, 523.31738421248383, 715.71125569520109, 978.83734991844688, 1338.6998597146596, 1830.8632323330951, 2503.9669281982829, 3424.532355440329, 4683.5370393234753, 6405.4057377695362, 8760.3070758200847, 11980.97094929486, 16385.688725918291, 22409.769304923335, 30648.559770668966, 41916.282280063475, 57326.501908367274, 78402.17791960774, 107226.17459483664, 146647.10628359963, 200560.85990769751, 274295.61718814232, 375138.42752394517, 513055.37160154793])
    dnde = np.array([1.3259335, 0.94195729, 0.66580701, 0.46162829, 0.30296713, 0.18484889, 0.10698333, 0.059697378, 0.032260861, 0.01673951, 0.0082548652, 0.0039907703, 0.0018546022, 0.00082937587, 0.0003599966, 0.00015557533, 6.7215013e-05, 2.8863404e-05, 1.2341489e-05, 5.3399754e-06, 2.2966778e-06, 9.9477847e-07, 4.53333e-07, 2.1135656e-07, 9.9832157e-08, 4.6697188e-08, 2.1986754e-08, 1.0368451e-08, 5.0197251e-09, 2.4097735e-09])
    
    E_bin_min,E_bin_max = int(np.argmin(np.abs(E-E_min))),  int(np.argmin(np.abs(E-E_max)))
    if E_bin_min <= E_bin_max: E_bin_max=E_bin_min+1
    
    return -np.log(dnde[E_bin_min]/dnde[E_bin_max])/np.log(E[E_bin_min]/E[E_bin_max])

    
    
GetSpectralIndex(1000,1e5)


#print len(energies)
# Out:
# ('SIMPLE', True, 'Written by IDL:  Wed May 15 12:11:40 2013')
# ('BITPIX', -32, 'number of bits per data pixel')
# ('NAXIS', 3, 'number of data axes')
# ('NAXIS1', 2880, 'length of data axis 1')
# ('NAXIS2', 1441, 'length of data axis 2')
# ('NAXIS3', 30, 'length of data axis 3')
# ('EXTEND', True, 'FITS dataset may contain extensions')
# ('COMMENT', "  FITS (Flexible Image Transport System) format is defined in 'Astronomy", '')
# ('COMMENT', "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H", '')
# ('CRVAL1', 0.0, 'Value of longitude in pixel CRPIX1')
# ('CDELT1', 0.125, 'Step size in longitude')
# ('CRPIX1', 1440.5, 'Pixel that has value CRVAL1')
# ('CTYPE1', 'GLON-CAR', 'The type of parameter 1 (Galactic longitude in')
# ('CUNIT1', 'deg', 'The unit of parameter 1')
# ('CRVAL2', 0.0, 'Value of latitude in pixel CRPIX2')
# ('CDELT2', 0.125, 'Step size in latitude')
# ('CRPIX2', 721.0, 'Pixel that has value CRVAL2')
# ('CTYPE2', 'GLAT-CAR', 'The type of parameter 2 (Galactic latitude in C')
# ('CUNIT2', 'deg', 'The unit of parameter 2')
# ('CRVAL3', 58.4731330871582, 'Energy of pixel CRPIX3')
# ('CDELT3', 0.135972685320041, 'log10 of step size in energy (if it is logarith')
# ('CRPIX3', 1.0, 'Pixel that has value CRVAL3')
# ('CTYPE3', 'Energy', 'Axis 3 is the spectra')
# ('CUNIT3', 'MeV', 'The unit of axis 3')
# ('CREATOR', 'chimgtyp 1.5', 's/w task that wrote this dataset')
# ('HISTORY', '', '')
# ('HISTORY', '---------------------------------------------------------', '')
# ('HISTORY', 'input file "model7_renorm_HE_lb_512.fits"', '')
# ('HISTORY', 'Initially input image format was  "DOUBLE"', '')
# ('HISTORY', 'Requested output image format is  "FLOAT"', '')
# ('HISTORY', 'Any undefined pixel values (if applicable) are set to -1.00e+37', '')
# ('HISTORY', '---------------------------------------------------------', '')
# ('HISTORY', '', '')
# ('DATE', '2013-04-02T04:57:43', 'file creation date (YYYY-MM-DDThh:mm:ss UT)')
# ('HISTORY', 'Scaled for V15 CLEAN IRFs by ratio of 4-year exposures for V10 IRFs', '')
# [1.3259335, 0.94195729, 0.66580701, 0.46162829, 0.30296713, 0.18484889, 0.10698333, 0.059697378, 0.032260861, 0.01673951, 0.0082548652, 0.0039907703, 0.0018546022, 0.00082937587, 0.0003599966, 0.00015557533, 6.7215013e-05, 2.8863404e-05, 1.2341489e-05, 5.3399754e-06, 2.2966778e-06, 9.9477847e-07, 4.53333e-07, 2.1135656e-07, 9.9832157e-08, 4.6697188e-08, 2.1986754e-08, 1.0368451e-08, 5.0197251e-09, 2.4097735e-09]
# 2.2580473033581874

# %%
hdu = pyfits.open('/home/carlson/fermitools/refdata/fermi/galdiffuse/gll_iem_v05.fits')
im = plt.imshow(np.log10(hdu[0].data[0]))
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7ff1f1dd7f38>
