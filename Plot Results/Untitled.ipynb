# %%
import h5py
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed',)).History will not be written to the database.

# %%
h = h5py.File('/data/GCE_sys/mod_c/mod_h_5_XCO_stripped.hdf5')
for i in h['/fit_results/']:
    
    print h['/fit_results/global/'].attrs['outerfval']
    print i
# Out:
# -5153023.96723
# GC
# -5153023.96723
# GC_no_dm
# -5153023.96723
# global
# -5153023.96723
# globalmask

# %%
print h['/fit_results/global/]
import healpy
#healpy.cartview(h['/fit_results/globalmask/'][...])
# Out:
#   File "<ipython-input-20-d35c2ddd2a0d>", line 1
#     print h['/fit_results/global/]
#                                  ^
# SyntaxError: EOL while scanning string literal

# %%
h = pyfits.open('../mod_c/nuclei_54_mod_m_10.gz')
h.info()
# Out:
# Filename: ../mod_c/nuclei_54_mod_m_10.gz
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU      40   (81, 1, 49, 7)   float32

# %%
import healpy
a = np.load('../binned_photons_P8R2_CLEAN_V6_calore.npy')


healpy.cartview(np.log10(np.sum(a[8:], axis=0)), max=4, min=1, xsize=1920,title='',cbar=None)
plt.savefig('/home/carlson/gamma_back.png', bbox_inches='tight')
# Out:
# /home/carlson/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: RuntimeWarning: divide by zero encountered in log10

# %%
gammas = np.linspace(.25,1.25,21)
axis_ratios = np.linspace(0.5,3.5,31)
loglike_total = np.zeros((len(gammas), len(axis_ratios)))
loglike, dm_spec, dm_spec_unc = [], [], []

for i_g, gamma in enumerate(gammas):
    loglike.append([])
    dm_spec.append([])
    dm_spec_unc.append([])
    
    for i_ar, axis_ratio in enumerate(axis_ratios):
        loglike[i_g].append(0)

# %%
print np.array(loglike).shape
# Out:
# (21, 31)
