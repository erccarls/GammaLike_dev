# %%
import h5py

best_fit = 12

for i in range(0,65):
    
    h5 = h5py.File('../mod_c/mod_e_'+str(i)+'_stripped.hdf5', 'r')
    for f in h5['/fit_results/']:
        print f
    try:    
        ll =  h5['/fit_results/localize/'].attrs['loglike_total']
        ar =  h5['/fit_results/localize/'].attrs['longitudes']
        print ar

        if i == best_fit:
            plt.plot(ar,2*(ll-min(ll)), c='k', alpha=1)
        else:
            plt.plot(ar,2*(ll-min(ll)), c='y', alpha=.25)
      
    except:
        pass
    

plt.ylabel(r'$2\Delta\log{(\mathcal{L})}$')
plt.xlabel(r'Axes Ratio')
#plt.ylim(0,4e3)
#plt.xlim(1,1.5)
# Out:
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# GC
# GC_no_dm
# scan_axesratio
# scan_gamma
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-5fa300613547> in <module>()
#       6
#       7     h5 = h5py.File('../mod_c/mod_e_'+str(i)+'_stripped.hdf5', 'r')
# ----> 8     for f in h5['/fit_results/']:
#       9         print f
#      10     try:
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (-------src-dir-------/h5py-2.4.0/h5py/_objects.c:2405)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (-------src-dir-------/h5py-2.4.0/h5py/_objects.c:2362)()
#
# /home/carlson/anaconda/lib/python2.7/site-packages/h5py/_hl/group.pyc in __getitem__(self, name)
#     158                 raise ValueError("Invalid HDF5 object reference")
#     159         else:
# --> 160             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     161
#     162         otype = h5i.get_type(oid)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (-------src-dir-------/h5py-2.4.0/h5py/_objects.c:2405)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (-------src-dir-------/h5py-2.4.0/h5py/_objects.c:2362)()
#
# h5py/h5o.pyx in h5py.h5o.open (-------src-dir-------/h5py-2.4.0/h5py/h5o.c:3456)()
#
# KeyError: "Unable to open object (Object 'fit_results' doesn't exist)"
