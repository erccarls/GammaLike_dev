# %%
# %pylab inline
import Template, Analysis
t = {'t':Template.Template(np.zeros(10)),}
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
print '%20s' % 'NAME', '%25s' % 'LIMITS', '%10s' % 'VALUE', '%10s' % 'FIX_NORM', '%10s' % 'FIX_SPEC'
for key in t:
            temp = t[key]
            print '%20s' % key, '%25s' % temp.limits, '%10s' % temp.value, '%10s' % temp.fixNorm, '%10s' % temp.fixSpectrum

# %%
reload(Analysis)

A = Analysis.Analysis()
A.AddPointSourceTemplate()

# %%
A.AddTemplate('test',np.zeros(10))
A.AddTemplate('test2',np.zeros(10))

A.PrintTemplates()

A.RemoveTemplate('test')
A.PrintTemplates()

# %%
E,flux,fluxUnc = np.genfromtxt('iso_clean_v05.txt').T




# Build a power law interpolator
fluxInterp = lambda x: np.exp(np.interp(np.log(x),np.log(E),np.log(flux)))
fluxUncInterp = lambda x: np.exp(np.interp(np.log(x),np.log(E),np.log(fluxUnc)))

fluxInterp(1)

# %%
f = np.zeros(shape=(1000,1000))
f2 = np.zeros(shape=(100,100))


# %timeit f[:100,:100]*f[:100,:100]
# %timeit f2*f2

# %%
a = np.ones(shape=(2,3,3))
print np.inner([2,3],a)

# %%
import Template, Analysis, Likelihood
reload(Analysis)
A = Analysis.Analysis()

# %%
A.AddIsotropicTemplate()
A.BinPhotons()
A.AddPointSourceTemplate()
A.GenSquareMask(l_range=[-20,20],b_range=[-20,20],plane_mask=2)
A.PrintTemplates()
# Out:
#                 NAME                    LIMITS      VALUE    FIXNORM    FIXSPEC   SRCCLASS
#                  PSC                [0, 100.0]          1      False      False        PSC
#            Isotropic             [0, 100000.0]          1       True       True        ISO

# %%
import GammaLikelihood as like
reload(like)
#healpy.mollview(A.binned_data[10])

m, res = like.RunLikelihood(A,print_level=2,use_basinhopping=True)
# Out:
# Masking completed in 2.2890e-02 s
# Code generation completed in 1.9685e-02 s
# 0 2.91601e+06
# 500 2.42909e+06
# 1000 2.13719e+06
# 1500 2.12504e+06
# 2000 2.12132e+06
# 2500 2.12132e+06
# 3000 2.11996e+06
# 3500 2.10785e+06
# 4000 253064.0
# GammaLikelihood.py:30: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if analysis.binned_data==None:
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = -32491.4707031</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 4089</td>
#                 <td title="Number of call in last migrad">NCALLS = 4076</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 6178773425.95</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.005</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#IQJvRfKLjq').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>PSC_0</td>
#                 <td>3.330408e+01</td>
#                 <td>7.146903e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>PSC_1</td>
#                 <td>5.672766e+01</td>
#                 <td>6.939211e+01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>PSC_2</td>
#                 <td>6.330680e+01</td>
#                 <td>3.527351e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>PSC_3</td>
#                 <td>9.276538e+01</td>
#                 <td>2.015931e+01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>PSC_4</td>
#                 <td>5.003118e+01</td>
#                 <td>1.444440e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>6</td>
#                 <td>PSC_5</td>
#                 <td>1.798187e+01</td>
#                 <td>6.162607e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>7</td>
#                 <td>PSC_6</td>
#                 <td>2.719611e+01</td>
#                 <td>3.086945e+01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>8</td>
#                 <td>PSC_7</td>
#                 <td>6.103635e+01</td>
#                 <td>2.439648e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>9</td>
#                 <td>PSC_8</td>
#                 <td>3.754229e+01</td>
#                 <td>3.931706e+01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>10</td>
#                 <td>PSC_9</td>
#                 <td>6.804375e+01</td>
#                 <td>3.144619e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>11</td>
#                 <td>PSC_10</td>
#                 <td>3.015475e+01</td>
#                 <td>3.713967e+01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>12</td>
#                 <td>PSC_11</td>
#                 <td>2.622492e+01</td>
#                 <td>1.208884e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>13</td>
#                 <td>PSC_12</td>
#                 <td>8.779863e+01</td>
#                 <td>1.959177e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>14</td>
#                 <td>PSC_13</td>
#                 <td>6.102425e+01</td>
#                 <td>3.765485e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>15</td>
#                 <td>PSC_14</td>
#                 <td>8.004952e+00</td>
#                 <td>6.381461e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>16</td>
#                 <td>PSC_15</td>
#                 <td>1.284063e+01</td>
#                 <td>2.716732e+01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>17</td>
#                 <td>PSC_16</td>
#                 <td>3.538762e+01</td>
#                 <td>7.756927e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>18</td>
#                 <td>PSC_17</td>
#                 <td>6.562992e+01</td>
#                 <td>7.620627e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>19</td>
#                 <td>PSC_18</td>
#                 <td>1.718384e+01</td>
#                 <td>3.173055e+01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>20</td>
#                 <td>PSC_19</td>
#                 <td>5.791583e+00</td>
#                 <td>6.999079e+01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>21</td>
#                 <td>PSC_20</td>
#                 <td>8.184652e-03</td>
#                 <td>1.397781e-04</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>100.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>22</td>
#                 <td>PSC_21</td>
#                 <td>2.9588
# <hr>
# Likelihood fit completed in 2.5238e+01 s
# basinhopping step 0: f 501850
# basinhopping step 1: f 492504 trial_f 492504 accepted 1  lowest_f 492504
# found new global minimum on step 1 with function value 492504
# basinhopping step 2: f 492504 trial_f 517145 accepted 0  lowest_f 492504
# basinhopping step 3: f 492504 trial_f 544576 accepted 0  lowest_f 492504
# basinhopping step 4: f 489988 trial_f 489988 accepted 1  lowest_f 489988
# found new global minimum on step 4 with function value 489988
# basinhopping step 5: f 459455 trial_f 459455 accepted 1  lowest_f 459455
# found new global minimum on step 5 with function value 459455
# basinhopping step 6: f -403901 trial_f -403901 accepted 1  lowest_f -403901
# found new global minimum on step 6 with function value -403901
# basinhopping step 7: f -406859 trial_f -406859 accepted 1  lowest_f -406859
# found new global minimum on step 7 with function value -406859
# basinhopping step 8: f -406859 trial_f -405486 accepted 0  lowest_f -406859
# basinhopping step 9: f -406859 trial_f -402269 accepted 0  lowest_f -406859
# basinhopping step 10: f -408488 trial_f -408488 accepted 1  lowest_f -408488
# found new global minimum on step 10 with function value -408488
# basinhopping step 11: f -408488 trial_f -406085 accepted 0  lowest_f -408488
# basinhopping step 12: f -408488 trial_f -405964 accepted 0  lowest_f -408488
# basinhopping step 13: f -412504 trial_f -412504 accepted 1  lowest_f -412504
# found new global minimum on step 13 with function value -412504
# basinhopping step 14: f -413132 trial_f -413132 accepted 1  lowest_f -413132
# found new global minimum on step 14 with function value -413132
# basinhopping step 15: f -413132 trial_f -412048 accepted 0  lowest_f -413132
# basinhopping step 16: f -413132 trial_f -408940 accepted 0  lowest_f -413132
# basinhopping step 17: f -415207 trial_f -415207 accepted 1  lowest_f -415207
# found new global minimum on step 17 with function value -415207
# basinhopping step 18: f -418989 trial_f -418989 accepted 1  lowest_f -418989
# found new global minimum on step 18 with function value -418989
# basinhopping step 19: f -421466 trial_f -421466 accepted 1  lowest_f -421466
# found new global minimum on step 19 with function value -421466
# basinhopping step 20: f -422504 trial_f -422504 accepted 1  lowest_f -422504
# found new global minimum on step 20 with function value -422504
# basinhopping step 21: f -424178 trial_f -424178 accepted 1  lowest_f -424178
# found new global minimum on step 21 with function value -424178
# basinhopping step 22: f -424178 trial_f -423178 accepted 0  lowest_f -424178
# basinhopping step 23: f -424178 trial_f -422284 accepted 0  lowest_f -424178
# basinhopping step 24: f -424178 trial_f -419435 accepted 0  lowest_f -424178
# basinhopping step 25: f -424178 trial_f -421580 accepted 0  lowest_f -424178
# basinhopping step 26: f -424178 trial_f -420669 accepted 0  lowest_f -424178
# basinhopping step 27: f -425664 trial_f -425664 accepted 1  lowest_f -425664
# found new global minimum on step 27 with function value -425664
# basinhopping step 28: f -426078 trial_f -426078 accepted 1  lowest_f -426078
# found new global minimum on step 28 with function value -426078
# basinhopping step 29: f -426078 trial_f -421147 accepted 0  lowest_f -426078
# basinhopping step 30: f -429539 trial_f -429539 accepted 1  lowest_f -429539
# found new global minimum on step 30 with function value -429539
# basinhopping step 31: f -429539 trial_f -426872 accepted 0  lowest_f -429539
# basinhopping step 32: f -431495 trial_f -431495 accepted 1  lowest_f -431495
# found new global minimum on step 32 with function value -431495
# basinhopping step 33: f -431495 trial_f -427888 accepted 0  lowest_f -431495
# basinhopping step 34: f -432906 trial_f -432906 accepted 1  lowest_f -432906
# found new global minimum on step 34 with function value -432906
# basinhopping step 35: f -436592 trial_f -436592 accepted 1  lowest_f -436592
# found new global minimum on step 35 with function value -436592
# basinhopping step 36: f -436592 trial_f -436197 accepted 0  lowest_f -436592
# basinhopping step 37: f -436592 trial_f -433452 accepted 0  lowest_f -436592
# basinhopping step 38: f -439457 trial_f -439457 accepted 1  lowest_f -439457
# found new global minimum on step 38 with function value -439457
# basinhopping step 39: f -439457 trial_f -436113 accepted 0  lowest_f -439457
# basinhopping step 40: f -442894 trial_f -442894 accepted 1  lowest_f -442894
# found new global minimum on step 40 with function value -442894
# basinhopping step 41: f -446254 trial_f -446254 accepted 1  lowest_f -446254
# found new global minimum on step 41 with function value -446254
# basinhopping step 42: f -448389 trial_f -448389 accepted 1  lowest_f -448389
# found new global minimum on step 42 with function value -448389
# basinhopping step 43: f -453954 trial_f -453954 accepted 1  lowest_f -453954
# found new global minimum on step 43 with function value -453954
# basinhopping step 44: f -453954 trial_f -451247 accepted 0  lowest_f -453954
# basinhopping step 45: f -457651 trial_f -457651 accepted 1  lowest_f -457651
# found new global minimum on step 45 with function value -457651
# basinhopping step 46: f -459432 trial_f -459432 accepted 1  lowest_f -459432
# found new global minimum on step 46 with function value -459432
# basinhopping step 47: f -459432 trial_f -454293 accepted 0  lowest_f -459432
# basinhopping step 48: f -460747 trial_f -460747 accepted 1  lowest_f -460747
# found new global minimum on step 48 with function value -460747
# basinhopping step 49: f -465808 trial_f -465808 accepted 1  lowest_f -465808
# found new global minimum on step 49 with function value -465808
# adaptive stepsize: acceptance rate 0.560000 target 0.500000 new stepsize 0.111111 old stepsize 0.1
# basinhopping step 50: f -465808 trial_f -465165 accepted 0  lowest_f -465808
# basinhopping step 51: f -465808 trial_f -465154 accepted 0  lowest_f -465808
# basinhopping step 52: f -466383 trial_f -466383 accepted 1  lowest_f -466383
# found new global minimum on step 52 with function value -466383
# basinhopping step 53: f -466383 trial_f -465169 accepted 0  lowest_f -466383
# basinhopping step 54: f -467809 trial_f -467809 accepted 1  lowest_f -467809
# found new global minimum on step 54 with function value -467809
# basinhopping step 55: f -467809 trial_f -465714 accepted 0  lowest_f -467809
# basinhopping step 56: f -467809 trial_f -463474 accepted 0  lowest_f -467809
# basinhopping step 57: f -472601 trial_f -472601 accepted 1  lowest_f -472601
# found new global minimum on step 57 with function value -472601
# basinhopping step 58: f -472601 trial_f -472116 accepted 0  lowest_f -472601
# basinhopping step 59: f -472601 trial_f -472160 accepted 0  lowest_f -472601
# basinhopping step 60: f -474474 trial_f -474474 accepted 1  lowest_f -474474
# found new global minimum on step 60 with function value -474474
# basinhopping step 61: f -474474 trial_f -471864 accepted 0  lowest_f -474474
# basinhopping step 62: f -478498 trial_f -478498 accepted 1  lowest_f -478498
# found new global minimum on step 62 with function value -478498
# basinhopping step 63: f -478498 trial_f -478162 accepted 0  lowest_f -478498
# basinhopping step 64: f -480418 trial_f -480418 accepted 1  lowest_f -480418
# found new global minimum on step 64 with function value -480418
# basinhopping step 65: f -480418 trial_f -479886 accepted 0  lowest_f -480418
# basinhopping step 66: f -480418 trial_f -477680 accepted 0  lowest_f -480418
# basinhopping step 67: f -480418 trial_f -476453 accepted 0  lowest_f -480418
# basinhopping step 68: f -482414 trial_f -482414 accepted 1  lowest_f -482414
# found new global minimum on step 68 with function value -482414
# basinhopping step 69: f -482414 trial_f -476236 accepted 0  lowest_f -482414
# basinhopping step 70: f -482414 trial_f -479044 accepted 0  lowest_f -482414
# basinhopping step 71: f -484047 trial_f -484047 accepted 1  lowest_f -484047
# found new global minimum on step 71 with function value -484047
# basinhopping step 72: f -484047 trial_f -481618 accepted 0  lowest_f -484047
# basinhopping step 73: f -484047 trial_f -479877 accepted 0  lowest_f -484047
# basinhopping step 74: f -484047 trial_f -483746 accepted 0  lowest_f -484047
# basinhopping step 75: f -489815 trial_f -489815 accepted 1  lowest_f -489815
# found new global minimum on step 75 with function value -489815
# basinhopping step 76: f -494176 trial_f -494176 accepted 1  lowest_f -494176
# found new global minimum on step 76 with function value -494176
# basinhopping step 77: f -494176 trial_f -489076 accepted 0  lowest_f -494176
# basinhopping step 78: f -494176 trial_f -492802 accepted 0  lowest_f -494176
# basinhopping step 79: f -497228 trial_f -497228 accepted 1  lowest_f -497228
# found new global minimum on step 79 with function value -497228
# basinhopping step 80: f -497228 trial_f -494787 accepted 0  lowest_f -497228
# basinhopping step 81: f -498486 trial_f -498486 accepted 1  lowest_f -498486
# found new global minimum on step 81 with function value -498486
# basinhopping step 82: f -498486 trial_f -492800 accepted 0  lowest_f -498486
# basinhopping step 83: f -498486 trial_f -496805 accepted 0  lowest_f -498486
# basinhopping step 84: f -502672 trial_f -502672 accepted 1  lowest_f -502672
# found new global minimum on step 84 with function value -502672
# basinhopping step 85: f -506293 trial_f -506293 accepted 1  lowest_f -506293
# found new global minimum on step 85 with function value -506293
# basinhopping step 86: f -506293 trial_f -503396 accepted 0  lowest_f -506293
# basinhopping step 87: f -506293 trial_f -505667 accepted 0  lowest_f -506293
# basinhopping step 88: f -508848 trial_f -508848 accepted 1  lowest_f -508848
# found new global minimum on step 88 with function value -508848
# basinhopping step 89: f -509533 trial_f -509533 accepted 1  lowest_f -509533
# found new global minimum on step 89 with function value -509533
# basinhopping step 90: f -509533 trial_f -507082 accepted 0  lowest_f -509533
# basinhopping step 91: f -509533 trial_f -506094 accepted 0  lowest_f -509533
# basinhopping step 92: f -512147 trial_f -512147 accepted 1  lowest_f -512147
# found new global minimum on step 92 with function value -512147
# basinhopping step 93: f -517629 trial_f -517629 accepted 1  lowest_f -517629
# found new global minimum on step 93 with function value -517629
# basinhopping step 94: f -517629 trial_f -515393 accepted 0  lowest_f -517629
# basinhopping step 95: f -517629 trial_f -516194 accepted 0  lowest_f -517629
# basinhopping step 96: f -517629 trial_f -511980 accepted 0  lowest_f -517629
# basinhopping step 97: f -517629 trial_f -513448 accepted 0  lowest_f -517629
# basinhopping step 98: f -520645 trial_f -520645 accepted 1  lowest_f -520645
# found new global minimum on step 98 with function value -520645
# basinhopping step 99: f -522744 trial_f -522744 accepted 1  lowest_f -522744
# found new global minimum on step 99 with function value -522744
# adaptive stepsize: acceptance rate 0.480000 target 0.500000 new stepsize 0.1 old stepsize 0.111111
# basinhopping step 100: f -522744 trial_f -517982 accepted 0  lowest_f -522744
# basinhopping step 101: f -1.19148e+06 trial_f -1.19148e+06 accepted 1  lowest_f -1.19148e+06
# found new global minimum on step 101 with function value -1.19148e+06
# basinhopping step 102: f -1.19222e+06 trial_f -1.19222e+06 accepted 1  lowest_f -1.19222e+06
# found new global minimum on step 102 with function value -1.19222e+06
# basinhopping step 103: f -1.19247e+06 trial_f -1.19247e+06 accepted 1  lowest_f -1.19247e+06
# found new global minimum on step 103 with function value -1.19247e+06
# basinhopping step 104: f -1.19252e+06 trial_f -1.19252e+06 accepted 1  lowest_f -1.19252e+06
# found new global minimum on step 104 with function value -1.19252e+06
# basinhopping step 105: f -1.19252e+06 trial_f -1.19247e+06 accepted 0  lowest_f -1.19252e+06
# basinhopping step 106: f -1.19276e+06 trial_f -1.19276e+06 accepted 1  lowest_f -1.19276e+06
# found new global minimum on step 106 with function value -1.19276e+06
# basinhopping step 107: f -1.19276e+06 trial_f -1.19266e+06 accepted 0  lowest_f -1.19276e+06
# basinhopping step 108: f -1.19276e+06 trial_f -1.1923e+06 accepted 0  lowest_f -1.19276e+06
# basinhopping step 109: f -1.19284e+06 trial_f -1.19284e+06 accepted 1  lowest_f -1.19284e+06
# found new global minimum on step 109 with function value -1.19284e+06
# basinhopping step 110: f -1.19306e+06 trial_f -1.19306e+06 accepted 1  lowest_f -1.19306e+06
# found new global minimum on step 110 with function value -1.19306e+06
# basinhopping step 111: f -1.19349e+06 trial_f -1.19349e+06 accepted 1  lowest_f -1.19349e+06
# found new global minimum on step 111 with function value -1.19349e+06
# basinhopping step 112: f -1.19363e+06 trial_f -1.19363e+06 accepted 1  lowest_f -1.19363e+06
# found new global minimum on step 112 with function value -1.19363e+06
# basinhopping step 113: f -1.19424e+06 trial_f -1.19424e+06 accepted 1  lowest_f -1.19424e+06
# found new global minimum on step 113 with function value -1.19424e+06
# basinhopping step 114: f -1.19442e+06 trial_f -1.19442e+06 accepted 1  lowest_f -1.19442e+06
# found new global minimum on step 114 with function value -1.19442e+06
# basinhopping step 115: f -1.19447e+06 trial_f -1.19447e+06 accepted 1  lowest_f -1.19447e+06
# found new global minimum on step 115 with function value -1.19447e+06
# basinhopping step 116: f -1.19447e+06 trial_f -1.19441e+06 accepted 0  lowest_f -1.19447e+06
# basinhopping step 117: f -1.19447e+06 trial_f -1.1941e+06 accepted 0  lowest_f -1.19447e+06
# basinhopping step 118: f -1.19447e+06 trial_f -1.19402e+06 accepted 0  lowest_f -1.19447e+06
# basinhopping step 119: f -1.19447e+06 trial_f -1.19434e+06 accepted 0  lowest_f -1.19447e+06
# basinhopping step 120: f -1.19447e+06 trial_f -1.19405e+06 accepted 0  lowest_f -1.19447e+06
# basinhopping step 121: f -1.19447e+06 trial_f -1.19444e+06 accepted 0  lowest_f -1.19447e+06
# basinhopping step 122: f -1.19447e+06 trial_f -1.19427e+06 accepted 0  lowest_f -1.19447e+06
# basinhopping step 123: f -1.19492e+06 trial_f -1.19492e+06 accepted 1  lowest_f -1.19492e+06
# found new global minimum on step 123 with function value -1.19492e+06
# basinhopping step 124: f -1.19492e+06 trial_f -1.19423e+06 accepted 0  lowest_f -1.19492e+06
# basinhopping step 125: f -1.19492e+06 trial_f -1.19429e+06 accepted 0  lowest_f -1.19492e+06
# basinhopping step 126: f -1.19492e+06 trial_f -1.19434e+06 accepted 0  lowest_f -1.19492e+06
# basinhopping step 127: f -1.19492e+06 trial_f -1.19446e+06 accepted 0  lowest_f -1.19492e+06
# basinhopping step 128: f -1.19498e+06 trial_f -1.19498e+06 accepted 1  lowest_f -1.19498e+06
# found new global minimum on step 128 with function value -1.19498e+06
# basinhopping step 129: f -1.19498e+06 trial_f -1.19417e+06 accepted 0  lowest_f -1.19498e+06
# basinhopping step 130: f -1.19527e+06 trial_f -1.19527e+06 accepted 1  lowest_f -1.19527e+06
# found new global minimum on step 130 with function value -1.19527e+06
# basinhopping step 131: f -1.19536e+06 trial_f -1.19536e+06 accepted 1  lowest_f -1.19536e+06
# found new global minimum on step 131 with function value -1.19536e+06
# basinhopping step 132: f -1.19593e+06 trial_f -1.19593e+06 accepted 1  lowest_f -1.19593e+06
# found new global minimum on step 132 with function value -1.19593e+06
# basinhopping step 133: f -1.19595e+06 trial_f -1.19595e+06 accepted 1  lowest_f -1.19595e+06
# found new global minimum on step 133 with function value -1.19595e+06
# basinhopping step 134: f -1.19622e+06 trial_f -1.19622e+06 accepted 1  lowest_f -1.19622e+06
# found new global minimum on step 134 with function value -1.19622e+06
# basinhopping step 135: f -1.19691e+06 trial_f -1.19691e+06 accepted 1  lowest_f -1.19691e+06
# found new global minimum on step 135 with function value -1.19691e+06
# basinhopping step 136: f -1.19691e+06 trial_f -1.19604e+06 accepted 0  lowest_f -1.19691e+06
# basinhopping step 137: f -1.19691e+06 trial_f -1.19685e+06 accepted 0  lowest_f -1.19691e+06
# basinhopping step 138: f -1.1972e+06 trial_f -1.1972e+06 accepted 1  lowest_f -1.1972e+06
# found new global minimum on step 138 with function value -1.1972e+06
# basinhopping step 139: f -1.1972e+06 trial_f -1.19711e+06 accepted 0  lowest_f -1.1972e+06
# basinhopping step 140: f -1.19737e+06 trial_f -1.19737e+06 accepted 1  lowest_f -1.19737e+06
# found new global minimum on step 140 with function value -1.19737e+06
# basinhopping step 141: f -1.19737e+06 trial_f -1.1969e+06 accepted 0  lowest_f -1.19737e+06
# basinhopping step 142: f -1.19737e+06 trial_f -1.197e+06 accepted 0  lowest_f -1.19737e+06
# basinhopping step 143: f -1.19771e+06 trial_f -1.19771e+06 accepted 1  lowest_f -1.19771e+06
# found new global minimum on step 143 with function value -1.19771e+06
# basinhopping step 144: f -1.19814e+06 trial_f -1.19814e+06 accepted 1  lowest_f -1.19814e+06
# found new global minimum on step 144 with function value -1.19814e+06
# basinhopping step 145: f -1.19814e+06 trial_f -1.19779e+06 accepted 0  lowest_f -1.19814e+06
# basinhopping step 146: f -1.19852e+06 trial_f -1.19852e+06 accepted 1  lowest_f -1.19852e+06
# found new global minimum on step 146 with function value -1.19852e+06
# basinhopping step 147: f -1.19852e+06 trial_f -1.19821e+06 accepted 0  lowest_f -1.19852e+06
# basinhopping step 148: f -1.19855e+06 trial_f -1.19855e+06 accepted 1  lowest_f -1.19855e+06
# found new global minimum on step 148 with function value -1.19855e+06
# basinhopping step 149: f -1.19907e+06 trial_f -1.19907e+06 accepted 1  lowest_f -1.19907e+06
# found new global minimum on step 149 with function value -1.19907e+06
# adaptive stepsize: acceptance rate 0.500000 target 0.500000 new stepsize 0.09 old stepsize 0.1
# basinhopping step 150: f -1.19953e+06 trial_f -1.19953e+06 accepted 1  lowest_f -1.19953e+06
# found new global minimum on step 150 with function value -1.19953e+06
# basinhopping step 151: f -1.19953e+06 trial_f -1.19934e+06 accepted 0  lowest_f -1.19953e+06
# basinhopping step 152: f -1.1998e+06 trial_f -1.1998e+06 accepted 1  lowest_f -1.1998e+06
# found new global minimum on step 152 with function value -1.1998e+06
# basinhopping step 153: f -1.20008e+06 trial_f -1.20008e+06 accepted 1  lowest_f -1.20008e+06
# found new global minimum on step 153 with function value -1.20008e+06
# basinhopping step 154: f -1.20008e+06 trial_f -1.19946e+06 accepted 0  lowest_f -1.20008e+06
# basinhopping step 155: f -1.20008e+06 trial_f -1.1997e+06 accepted 0  lowest_f -1.20008e+06
# basinhopping step 156: f -1.20028e+06 trial_f -1.20028e+06 accepted 1  lowest_f -1.20028e+06
# found new global minimum on step 156 with function value -1.20028e+06
# basinhopping step 157: f -1.2005e+06 trial_f -1.2005e+06 accepted 1  lowest_f -1.2005e+06
# found new global minimum on step 157 with function value -1.2005e+06
# basinhopping step 158: f -1.2005e+06 trial_f -1.20037e+06 accepted 0  lowest_f -1.2005e+06
# basinhopping step 159: f -1.2005e+06 trial_f -1.20046e+06 accepted 0  lowest_f -1.2005e+06
# basinhopping step 160: f -1.2005e+06 trial_f -1.20031e+06 accepted 0  lowest_f -1.2005e+06
# basinhopping step 161: f -1.2007e+06 trial_f -1.2007e+06 accepted 1  lowest_f -1.2007e+06
# found new global minimum on step 161 with function value -1.2007e+06
# basinhopping step 162: f -1.20094e+06 trial_f -1.20094e+06 accepted 1  lowest_f -1.20094e+06
# found new global minimum on step 162 with function value -1.20094e+06
# basinhopping step 163: f -1.20133e+06 trial_f -1.20133e+06 accepted 1  lowest_f -1.20133e+06
# found new global minimum on step 163 with function value -1.20133e+06
# basinhopping step 164: f -1.20133e+06 trial_f -1.20101e+06 accepted 0  lowest_f -1.20133e+06
# basinhopping step 165: f -1.2016e+06 trial_f -1.2016e+06 accepted 1  lowest_f -1.2016e+06
# found new global minimum on step 165 with function value -1.2016e+06
# basinhopping step 166: f -1.2016e+06 trial_f -1.20137e+06 accepted 0  lowest_f -1.2016e+06
# basinhopping step 167: f -1.2016e+06 trial_f -1.2014e+06 accepted 0  lowest_f -1.2016e+06
# basinhopping step 168: f -1.20175e+06 trial_f -1.20175e+06 accepted 1  lowest_f -1.20175e+06
# found new global minimum on step 168 with function value -1.20175e+06
# basinhopping step 169: f -1.20175e+06 trial_f -1.20142e+06 accepted 0  lowest_f -1.20175e+06
# basinhopping step 170: f -1.2022e+06 trial_f -1.2022e+06 accepted 1  lowest_f -1.2022e+06
# found new global minimum on step 170 with function value -1.2022e+06
# basinhopping step 171: f -1.2022e+06 trial_f -1.20218e+06 accepted 0  lowest_f -1.2022e+06
# basinhopping step 172: f -1.2022e+06 trial_f -1.20183e+06 accepted 0  lowest_f -1.2022e+06
# basinhopping step 173: f -1.2022e+06 trial_f -1.2022e+06 accepted 0  lowest_f -1.2022e+06
# basinhopping step 174: f -1.2022e+06 trial_f -1.20178e+06 accepted 0  lowest_f -1.2022e+06
# basinhopping step 175: f -1.20253e+06 trial_f -1.20253e+06 accepted 1  lowest_f -1.20253e+06
# found new global minimum on step 175 with function value -1.20253e+06
# basinhopping step 176: f -1.20253e+06 trial_f -1.20218e+06 accepted 0  lowest_f -1.20253e+06
# basinhopping step 177: f -1.20253e+06 trial_f -1.20248e+06 accepted 0  lowest_f -1.20253e+06
# basinhopping step 178: f -1.20253e+06 trial_f -1.20241e+06 accepted 0  lowest_f -1.20253e+06
# /home/carlson/anaconda/lib/python2.7/site-packages/scipy/optimize/_basinhopping.py:290: RuntimeWarning: overflow encountered in exp
#   w = min(1.0, np.exp(-(energy_new - energy_old) * self.beta))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-fabe5a713c9d> in <module>()
#       3 #healpy.mollview(A.binned_data[10])
#       4
# ----> 5 m, res = like.RunLikelihood(A,print_level=2,use_basinhopping=True)
#       6
#
# /data/GCE_sys/GammaLikelihood.pyc in RunLikelihood(analysis, print_level, use_basinhopping, start_fresh, niter_success)
#     202     if (use_basinhopping==True):
#     203         res = basinhopping(like.f2,x0,niter=20000,disp=bool(print_level),
# --> 204                             stepsize=.1,minimizer_kwargs={'bounds':bounds},niter_success=niter_success)
#     205
#     206         return m, res
#
# /home/carlson/anaconda/lib/python2.7/site-packages/scipy/optimize/_basinhopping.pyc in basinhopping(func, x0, niter, T, stepsize, minimizer_kwargs, take_step, accept_test, callback, interval, disp, niter_success)
#     610                " successfully"]
#     611     for i in range(niter):
# --> 612         new_global_min = bh.one_cycle()
#     613
#     614         if isinstance(callback, collections.Callable):
#
# /home/carlson/anaconda/lib/python2.7/site-packages/scipy/optimize/_basinhopping.pyc in one_cycle(self)
#     154         new_global_min = False
#     155
# --> 156         xtrial, energy_trial, accept = self._monte_carlo_step()
#     157
#     158         if accept:
#
# /home/carlson/anaconda/lib/python2.7/site-packages/scipy/optimize/_basinhopping.pyc in _monte_carlo_step(self)
#     102
#     103         # do a local minimization
# --> 104         minres = self.minimizer(x_after_step)
#     105         x_after_quench = minres.x
#     106         energy_after_quench = minres.fun
#
# /home/carlson/anaconda/lib/python2.7/site-packages/scipy/optimize/_basinhopping.pyc in __call__(self, x0)
#     277             return self.minimizer(x0, **self.kwargs)
#     278         else:
# --> 279             return self.minimizer(self.func, x0, **self.kwargs)
#     280
#     281
#
# /home/carlson/anaconda/lib/python2.7/site-packages/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     425     elif meth == 'l-bfgs-b':
#     426         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 427                                 callback=callback, **options)
#     428     elif meth == 'tnc':
#     429         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# /home/carlson/anaconda/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, **unknown_options)
#     312                 # minimization routine wants f and g at the current x
#     313                 # Overwrite f and g:
# --> 314                 f, g = func_and_grad(x)
#     315         elif task_str.startswith(b'NEW_X'):
#     316             # new iteration
#
# /home/carlson/anaconda/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in func_and_grad(x)
#     259         def func_and_grad(x):
#     260             f = fun(x, *args)
# --> 261             g = approx_fprime(x, fun, epsilon, *args)
#     262             return f, g
#     263     else:
#
# /home/carlson/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in approx_fprime(xk, f, epsilon, *args)
#     608         ei[k] = 1.0
#     609         d = epsilon * ei
# --> 610         grad[k] = (f(*((xk + d,) + args)) - f0) / d[k]
#     611         ei[k] = 0.0
#     612
#
# /home/carlson/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     279     def function_wrapper(*wrapper_args):
#     280         ncalls[0] += 1
# --> 281         return function(*(wrapper_args + args))
#     282
#     283     return ncalls, function_wrapper
#
# /tmp/tmp00dHLa in f2(self, x0)
#      74         model[9]=PSC_9*self.templateList['PSC'].healpixCubeMasked[9]+Isotropic*self.templateList['Isotropic'].healpixCubeMasked[9]
#      75         model[10]=PSC_10*self.templateList['PSC'].healpixCubeMasked[10]+Isotropic*self.templateList['Isotropic'].healpixCubeMasked[10]
# ---> 76         model[11]=PSC_11*self.templateList['PSC'].healpixCubeMasked[11]+Isotropic*self.templateList['Isotropic'].healpixCubeMasked[11]
#      77         model[12]=PSC_12*self.templateList['PSC'].healpixCubeMasked[12]+Isotropic*self.templateList['Isotropic'].healpixCubeMasked[12]
#      78         model[13]=PSC_13*self.templateList['PSC'].healpixCubeMasked[13]+Isotropic*self.templateList['Isotropic'].healpixCubeMasked[13]
#
# KeyboardInterrupt:

# %%
for i in range(24):
    print np.mean(A.templateList['PSC'].healpixCube[i]),np.mean(A.binned_data[i])

# %%
print m.fitarg
norms=[]
bins = []
for i in range(24):
    bins.append(A.bin_edges[i])
    norms.append( m.fitarg['PSC_'+str(i)])
    
plt.loglog(bins,norms)    

print A.mask
idx = np.where(A.mask!=0)[0]
np.mean(A.binned_data[0,idx])

# %%
print list(A.bin_edges
# Out:
# [300, 350, 400, 450, 500, 557.4511962326, 624.9931144482831, 705.0811841511901, 800.9547380631948, 916.9544789959854, 1058.9994895010252, 1235.32183584898, 1457.6298200740125, 1743.0094229290717, 2117.148088832825, 2620.038055486477, 3316.5858204132596, 4317.5724796525965, 5824.226374320851, 8232.171915073328, 12404.648624640446, 20517.115667189668, 39361.808463774716, 99337.18520898951, 499999.9999999654]

# %%
x = np.vectorize(log)
# %timeit np.log(a)
# %timeit np.sum(a)

# %%
print len(np.nonzero(A.GenSquareMask(l_range=[-20,20],b_range=[-20,20],plane_mask=2))[0])
print np.shape(np.nonzero(A.mask))

# %%
import pycuda.driver as drv
import pycuda.tools
import pycuda.autoinit
import numpy
import numpy.linalg as la
from pycuda.compiler import SourceModule

mod = SourceModule("""
__global__ void multiply_them(float *dest, float *a, float *b)
{
  const int i = threadIdx.x;
  dest[i] = a[i] * b[i];
}
""")

multiply_them = mod.get_function("multiply_them")

a = numpy.random.randn(400).astype(numpy.float32)
b = numpy.random.randn(400).astype(numpy.float32)

dest = numpy.zeros_like(a)
#multiply_them(
#        drv.Out(dest), drv.In(a), drv.In(b),
#        block=(40000,1,1))

#print dest-a*b

# %timeit multiply_them(drv.Out(dest), drv.In(a), drv.In(b),block=(400,1,1))

# %timeit a*b

# %%
import pycuda.driver as drv

# %%
import numpy as np
import cudamat as cm

cm.cublas_init()

# create two random matrices and copy them to the GPU
a = cm.CUDAMatrix(np.random.rand(320, 2560))
b = cm.CUDAMatrix(np.random.rand(2560, 320))

# perform calculations on the GPU
# %timeit c = cm.dot(a, b)
# %timeit d = c.sum(axis = 0)



a = np.random.rand(320, 2560)
b = np.random.rand(2560, 320)

# %timeit np.dot(a,b)
# %timeit np.sum(b)

# copy d back to the host (CPU) and print
print d.asarray()

# %%
a = cm.CUDAMatrix(np.random.rand(24, 26786))
b = cm.CUDAMatrix(np.random.rand(24, 26786))

cm.dot(a,b.T)
# %timeit cm.log(a).asarray()

# %%
a = np.random.rand(320, 2560)
# %timeit cm.CUDAMatrix(a)

# %%
a = cm.CUDAMatrix(np.zeros((2, 2)))
a.add(np.e**2 target=)
print cm.log(a).asarray()
print a.asarray()

# %%
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
b, l = np.deg2rad((b,l))
d = np.rad2deg(np.arctan2(np.sqrt(np.square(np.cos(b)*np.sin(l) )+np.square(np.sin(b))),np.cos(b)*np.cos(l) ))
print d
# Out:
# 27.9908907178

# %%
np.sqrt((20**2+20**2))
# Out:
# 28.284271247461902

# %%
# Out:
# <module 'DM' from 'DM.py'>

# %%
import DM
import healpy
reload(DM)
healpy.cartview(DM.GenNFW(decay=False, axesratio=1,offset=(0,0),mult_solid_ang=True))
#healpy.cartview(DM.GenNFW(),latra=(-30,30),lonra=(-30,30))

import Template, Analysis
import GammaLikelihood as like
reload(Analysis)
A = Analysis.Analysis()
A.BinPhotons()

# %%
import pyfits
hdu = pyfits.open('/data/fermi_data_1-8-14/gtsrcmap_ALL_BOTH.fits')
hdu.info()

plt.imshow(hdu[0].data[0])
plt.colorbar()
plt.show()

plt.imshow(A.binned_data)
plt.colorbar()


print A.binned_data[0]
# Out:
# Filename: /data/fermi_data_1-8-14/gtsrcmap_ALL_BOTH.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU      50   (2881, 1441, 24)   float32
# 1    GTI         BinTableHDU     33   32441R x 2C   [D, D]
# 2    EBOUNDS     BinTableHDU     38   24R x 3C     [I, 1E, 1E]
# 3    2FGL J1328.5-4728  ImageHDU        24   (2881, 1441, 25)   float32
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-1015c83831e4> in <module>()
#       5 plt.imshow(hdu[0].data[0])
#       6
# ----> 7 print A
#
# NameError: name 'A' is not defined
