# %%
import Analysis
import cPickle as pickle
reload(Analysis)

A = Analysis.Analysis(tag='P7REP_CLEAN_V15_calore')

A.GenSquareMask(l_range=[-20.,20.], b_range=[-20.,20.], plane_mask=2.)
A.BinPhotons(infile='binned_photons_'+A.tag+'.npy')

A.AddPointSourceTemplate(fixNorm=True,pscmap='PSC_3FGL_with_ext.npy')


A.CalculatePixelWeights(diffuse_model='fermi_diffuse_'+A.tag+'.npy',psc_model='PSC_3FGL_with_ext.npy',
                        alpha_psc=5., f_psc=0.1)


A.AddIsotropicTemplate(fixNorm=False, fixSpectrum=False) # External chi^2 used to fix normalization within uncertainties

A.AddFermiBubbleTemplate(template_file='./bubble_templates_diskcut30.0.fits', 
                         spec_file='./reduced_bubble_spec_apj_793_64.dat', fixSpectrum=False)


A.AddFermiDiffuseModel(diffuse_path='/data/GCE_sys/gll_iem_v02_P6_V11_DIFFUSE.fit', multiplier=1., fixSpectrum=False)
#A.AddFermiDiffuseModel(diffuse_path='/data/fermi_background_models/gal_2yearp7v6_v0.fits', multiplier=1., fixSpectrum=False)

A.AddDMTemplate(profile='NFW', limits=[None,None], decay=False, gamma=1.26, 
                r_s=20.0, axesratio=1, offset=(0, 0), spec_file=None,)



A.PrintTemplates()
# Out:
# Remapping Fermi Diffuse Model to Healpix Grid 100.00 %                 NAME                    LIMITS      VALUE    FIXNORM    FIXSPEC   SRCCLASS
#                  PSC              [None, None]  1.000e+00       True       True        PSC
#              Bubbles              [None, None]  1.000e+00      False      False        GEN
#                   DM              [None, None]  1.000e+00      False      False        GEN
#            Isotropic              [None, None]  1.000e+00      False      False        ISO
#         FermiDiffuse              [None, None]  1.000e+00      False      False        GEN

# %%
A.ResetFit()
A.RunLikelihood(print_level=1, tol=2e3, precision=None, minos=False)[0]
# Out:
# Masking completed in 1.8519e-01 s
# Write likelihood tempfile to  /tmp/tmp2FGESB
# Code generation completed in 1.1330e-03 s
# Fallback to CPU mode.  (Failed to import cudamat libraries.)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = -365225.008133</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 181</td>
#                 <td title="Number of call in last migrad">NCALLS = 181</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 0.00809541571606</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.1</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#mgVVFKHRFp').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>PSC</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>Bubbles_0</td>
#                 <td>1.198755e+00</td>
#                 <td>1.599868e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>DM_0</td>
#                 <td>3.363621e+00</td>
#                 <td>7.114498e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>Isotropic_0</td>
#                 <td>2.183851e-02</td>
#                 <td>6.544232e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>FermiDiffuse_0</td>
#                 <td>1.076300e+00</td>
#                 <td>5.161926e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="mgVVFKHRFp" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & PSC & 1.000e+00 & 0.000e+00 &  &  &  &  & FIXED\\
# \hline
# 2 & $Bubbles_{0}$ & 1.199e+00 & 1.600e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 3 & $DM_{0}$ & 3.364e+00 & 7.114e+00 &  &  &  &  & \\
# \hline
# 4 & $Isotropic_{0}$ & 2.184e-02 & 6.544e-02 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 5 & $FermiDiffuse_{0}$ & 1.076e+00 & 5.162e-03 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# Migrad completed fitting   2.18e-01 s
# Masking completed in 1.1523e-01 s
# Write likelihood tempfile to  /tmp/tmplr185P
# Code generation completed in 9.7704e-04 s
# Fallback to CPU mode.  (Failed to import cudamat libraries.)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = -273699.218685</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 140</td>
#                 <td title="Number of call in last migrad">NCALLS = 140</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 0.0858721777633</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.1</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#nYDEDCIpFN').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>PSC</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>Bubbles_1</td>
#                 <td>8.812095e-01</td>
#                 <td>2.029464e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>DM_1</td>
#                 <td>6.607904e-02</td>
#                 <td>3.529105e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>Isotropic_1</td>
#                 <td>8.327776e-02</td>
#                 <td>1.378568e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>FermiDiffuse_1</td>
#                 <td>1.059159e+00</td>
#                 <td>6.273286e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="nYDEDCIpFN" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & PSC & 1.000e+00 & 0.000e+00 &  &  &  &  & FIXED\\
# \hline
# 2 & $Bubbles_{1}$ & 8.812e-01 & 2.029e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 3 & $DM_{1}$ & 6.608e-02 & 3.529e-02 &  &  &  &  & \\
# \hline
# 4 & $Isotropic_{1}$ & 8.328e-02 & 1.379e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 5 & $FermiDiffuse_{1}$ & 1.059e+00 & 6.273e-03 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# Migrad completed fitting   1.58e-01 s
# Masking completed in 1.1458e-01 s
# Write likelihood tempfile to  /tmp/tmpmAUnu3
# Code generation completed in 9.3102e-04 s
# Fallback to CPU mode.  (Failed to import cudamat libraries.)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = -202367.81534</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 118</td>
#                 <td title="Number of call in last migrad">NCALLS = 118</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 0.0617301165291</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.1</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#zalekIeONR').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>PSC</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>Bubbles_2</td>
#                 <td>1.038496e+00</td>
#                 <td>1.844824e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>DM_2</td>
#                 <td>7.186737e-02</td>
#                 <td>3.832384e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>Isotropic_2</td>
#                 <td>1.240066e-01</td>
#                 <td>1.345988e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>FermiDiffuse_2</td>
#                 <td>1.051358e+00</td>
#                 <td>6.321645e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="zalekIeONR" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & PSC & 1.000e+00 & 0.000e+00 &  &  &  &  & FIXED\\
# \hline
# 2 & $Bubbles_{2}$ & 1.038e+00 & 1.845e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 3 & $DM_{2}$ & 7.187e-02 & 3.832e-02 &  &  &  &  & \\
# \hline
# 4 & $Isotropic_{2}$ & 1.240e-01 & 1.346e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 5 & $FermiDiffuse_{2}$ & 1.051e+00 & 6.322e-03 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# Migrad completed fitting   1.34e-01 s
# Masking completed in 1.5133e-01 s
# Write likelihood tempfile to  /tmp/tmpkFyFxM
# Code generation completed in 9.4008e-04 s
# Fallback to CPU mode.  (Failed to import cudamat libraries.)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = -148999.748117</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 109</td>
#                 <td title="Number of call in last migrad">NCALLS = 109</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 0.0867870494281</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.1</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#vdkgAlxANV').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>PSC</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>Bubbles_3</td>
#                 <td>8.738703e-01</td>
#                 <td>1.701551e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>DM_3</td>
#                 <td>4.991611e-01</td>
#                 <td>1.682629e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>Isotropic_3</td>
#                 <td>1.440625e-01</td>
#                 <td>1.187846e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>FermiDiffuse_3</td>
#                 <td>1.043157e+00</td>
#                 <td>6.257968e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="vdkgAlxANV" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & PSC & 1.000e+00 & 0.000e+00 &  &  &  &  & FIXED\\
# \hline
# 2 & $Bubbles_{3}$ & 8.739e-01 & 1.702e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 3 & $DM_{3}$ & 4.992e-01 & 1.683e-01 &  &  &  &  & \\
# \hline
# 4 & $Isotropic_{3}$ & 1.441e-01 & 1.188e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 5 & $FermiDiffuse_{3}$ & 1.043e+00 & 6.258e-03 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# Migrad completed fitting   1.23e-01 s
# Masking completed in 1.5355e-01 s
# Write likelihood tempfile to  /tmp/tmpL32WXx
# Code generation completed in 9.1887e-04 s
# Fallback to CPU mode.  (Failed to import cudamat libraries.)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = -140627.361976</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 110</td>
#                 <td title="Number of call in last migrad">NCALLS = 110</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 0.00951939707151</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.1</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#lskYvafhgb').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>PSC</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>Bubbles_4</td>
#                 <td>7.790486e-01</td>
#                 <td>1.648441e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>DM_4</td>
#                 <td>5.021647e-01</td>
#                 <td>2.675023e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>Isotropic_4</td>
#                 <td>2.611575e-01</td>
#                 <td>1.245865e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>FermiDiffuse_4</td>
#                 <td>1.062344e+00</td>
#                 <td>6.424767e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="lskYvafhgb" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & PSC & 1.000e+00 & 0.000e+00 &  &  &  &  & FIXED\\
# \hline
# 2 & $Bubbles_{4}$ & 7.790e-01 & 1.648e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 3 & $DM_{4}$ & 5.022e-01 & 2.675e-01 &  &  &  &  & \\
# \hline
# 4 & $Isotropic_{4}$ & 2.612e-01 & 1.246e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 5 & $FermiDiffuse_{4}$ & 1.062e+00 & 6.425e-03 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# Migrad completed fitting   1.25e-01 s
# Masking completed in 1.5504e-01 s
# Write likelihood tempfile to  /tmp/tmpZKGEdB
# Code generation completed in 9.6893e-04 s
# Fallback to CPU mode.  (Failed to import cudamat libraries.)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = -135390.56326</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 108</td>
#                 <td title="Number of call in last migrad">NCALLS = 108</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 0.0537981884695</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.1</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#IHCjzFXwXY').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>PSC</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>Bubbles_5</td>
#                 <td>7.701608e-01</td>
#                 <td>1.569826e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>DM_5</td>
#                 <td>1.202266e-01</td>
#                 <td>2.433258e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>Isotropic_5</td>
#                 <td>2.227509e-01</td>
#                 <td>1.224740e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>FermiDiffuse_5</td>
#                 <td>1.027908e+00</td>
#                 <td>6.262155e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="IHCjzFXwXY" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & PSC & 1.000e+00 & 0.000e+00 &  &  &  &  & FIXED\\
# \hline
# 2 & $Bubbles_{5}$ & 7.702e-01 & 1.570e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 3 & $DM_{5}$ & 1.202e-01 & 2.433e-02 &  &  &  &  & \\
# \hline
# 4 & $Isotropic_{5}$ & 2.228e-01 & 1.225e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 5 & $FermiDiffuse_{5}$ & 1.028e+00 & 6.262e-03 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# Migrad completed fitting   1.23e-01 s
# Masking completed in 1.7104e-01 s
# Write likelihood tempfile to  /tmp/tmpoqgC8p
# Code generation completed in 8.9502e-04 s
# Fallback to CPU mode.  (Failed to import cudamat libraries.)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = -129292.575487</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 109</td>
#                 <td title="Number of call in last migrad">NCALLS = 109</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 0.0183975338746</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.1</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#xojVZJwhan').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>PSC</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>Bubbles_6</td>
#                 <td>8.152148e-01</td>
#                 <td>1.384253e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>DM_6</td>
#                 <td>1.509407e-01</td>
#                 <td>2.414733e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>Isotropic_6</td>
#                 <td>3.803962e-01</td>
#                 <td>1.012817e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>FermiDiffuse_6</td>
#                 <td>1.020934e+00</td>
#                 <td>5.981984e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="xojVZJwhan" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & PSC & 1.000e+00 & 0.000e+00 &  &  &  &  & FIXED\\
# \hline
# 2 & $Bubbles_{6}$ & 8.152e-01 & 1.384e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 3 & $DM_{6}$ & 1.509e-01 & 2.415e-02 &  &  &  &  & \\
# \hline
# 4 & $Isotropic_{6}$ & 3.804e-01 & 1.013e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 5 & $FermiDiffuse_{6}$ & 1.021e+00 & 5.982e-03 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# Migrad completed fitting   1.24e-01 s
# Masking completed in 1.8557e-01 s
# Write likelihood tempfile to  /tmp/tmpkkXJpG
# Code generation completed in 9.5892e-04 s
# Fallback to CPU mode.  (Failed to import cudamat libraries.)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = -118638.02424</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 105</td>
#                 <td title="Number of call in last migrad">NCALLS = 105</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 0.000771581440467</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.1</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#YPCrnFGBhj').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>PSC</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>Bubbles_7</td>
#                 <td>8.485948e-01</td>
#                 <td>1.271186e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>DM_7</td>
#                 <td>1.474064e-01</td>
#                 <td>2.937981e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>Isotropic_7</td>
#                 <td>4.509680e-01</td>
#                 <td>9.761948e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>FermiDiffuse_7</td>
#                 <td>1.004923e+00</td>
#                 <td>5.850814e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="YPCrnFGBhj" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & PSC & 1.000e+00 & 0.000e+00 &  &  &  &  & FIXED\\
# \hline
# 2 & $Bubbles_{7}$ & 8.486e-01 & 1.271e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 3 & $DM_{7}$ & 1.474e-01 & 2.938e-02 &  &  &  &  & \\
# \hline
# 4 & $Isotropic_{7}$ & 4.510e-01 & 9.762e-02 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 5 & $FermiDiffuse_{7}$ & 1.005e+00 & 5.851e-03 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# Migrad completed fitting   1.20e-01 s
# Masking completed in 1.9920e-01 s
# Write likelihood tempfile to  /tmp/tmpDwqMKd
# Code generation completed in 9.2411e-04 s
# Fallback to CPU mode.  (Failed to import cudamat libraries.)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = -107822.255009</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 109</td>
#                 <td title="Number of call in last migrad">NCALLS = 109</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 1.1891007879e-05</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.1</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
# ...
#             Bubbles_21
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             DM_21
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             Isotropic_21
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             FermiDiffuse_21
#             </div>
#             </div>
#             </td>
#
#                 </tr>
#
#             <tr>
#                 <td>Bubbles_21</td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(176,235,176)">
#                 -0.14
#                 </td>
#
#                 <td style="background-color:rgb(181,228,173)">
#                 -0.19
#                 </td>
#
#                 <td style="background-color:rgb(185,221,170)">
#                 -0.24
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>DM_21</td>
#
#                 <td style="background-color:rgb(176,235,176)">
#                 -0.14
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(165,251,184)">
#                 0.02
#                 </td>
#
#                 <td style="background-color:rgb(223,164,141)">
#                 -0.66
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>Isotropic_21</td>
#
#                 <td style="background-color:rgb(181,228,173)">
#                 -0.19
#                 </td>
#
#                 <td style="background-color:rgb(165,251,184)">
#                 0.02
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(181,227,172)">
#                 -0.20
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>FermiDiffuse_21</td>
#
#                 <td style="background-color:rgb(185,221,170)">
#                 -0.24
#                 </td>
#
#                 <td style="background-color:rgb(223,164,141)">
#                 -0.66
#                 </td>
#
#                 <td style="background-color:rgb(181,227,172)">
#                 -0.20
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#             </tr>
#             </table>
#
#             <pre id="KgGCCexfEU" style="display:none;">
#             <textarea rows="17" cols="50" onclick="this.select()" readonly>%\usepackage[table]{xcolor} % include this for color
# %\usepackage{rotating} % include this for rotate header
# %\documentclass[xcolor=table]{beamer} % for beamer
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# \rotatebox{90}{} & \rotatebox{90}{$Bubbles_{21}$} & \rotatebox{90}{$DM_{21}$} & \rotatebox{90}{$Isotropic_{21}$} & \rotatebox{90}{$FermiDiffuse_{21}$}\\
# \hline
# $Bubbles_{21}$ & \cellcolor[RGB]{255,117,117} 1.00 & \cellcolor[RGB]{176,235,176} -0.14 & \cellcolor[RGB]{181,228,173} -0.19 & \cellcolor[RGB]{185,221,170} -0.24\\
# \hline
# $DM_{21}$ & \cellcolor[RGB]{176,235,176} -0.14 & \cellcolor[RGB]{255,117,117} 1.00 & \cellcolor[RGB]{165,251,184} 0.02 & \cellcolor[RGB]{223,164,141} -0.66\\
# \hline
# $Isotropic_{21}$ & \cellcolor[RGB]{181,228,173} -0.19 & \cellcolor[RGB]{165,251,184} 0.02 & \cellcolor[RGB]{255,117,117} 1.00 & \cellcolor[RGB]{181,227,172} -0.20\\
# \hline
# $FermiDiffuse_{21}$ & \cellcolor[RGB]{185,221,170} -0.24 & \cellcolor[RGB]{223,164,141} -0.66 & \cellcolor[RGB]{181,227,172} -0.20 & \cellcolor[RGB]{255,117,117} 1.00\\
# \hline
# \end{tabular}</textarea>
#             </pre>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#emLODRKRwp').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>PSC</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>Bubbles_22</td>
#                 <td>8.382062e-01</td>
#                 <td>7.964909e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>DM_22</td>
#                 <td>1.848853e+00</td>
#                 <td>7.699261e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>Isotropic_22</td>
#                 <td>9.211007e-01</td>
#                 <td>1.237766e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>FermiDiffuse_22</td>
#                 <td>6.579841e-01</td>
#                 <td>2.554393e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="emLODRKRwp" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & PSC & 1.000e+00 & 0.000e+00 &  &  &  &  & FIXED\\
# \hline
# 2 & $Bubbles_{22}$ & 8.382e-01 & 7.965e-02 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 3 & $DM_{22}$ & 1.849e+00 & 7.699e-01 &  &  &  &  & \\
# \hline
# 4 & $Isotropic_{22}$ & 9.211e-01 & 1.238e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 5 & $FermiDiffuse_{22}$ & 6.580e-01 & 2.554e-02 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
#             <table>
#                 <tr>
#                     <td><a onclick="$('#NJPConXgfs').toggle()" href="#">+</a></td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             Bubbles_22
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             DM_22
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             Isotropic_22
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             FermiDiffuse_22
#             </div>
#             </div>
#             </td>
#
#                 </tr>
#
#             <tr>
#                 <td>Bubbles_22</td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(175,237,177)">
#                 -0.13
#                 </td>
#
#                 <td style="background-color:rgb(175,237,177)">
#                 -0.13
#                 </td>
#
#                 <td style="background-color:rgb(182,225,172)">
#                 -0.21
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>DM_22</td>
#
#                 <td style="background-color:rgb(175,237,177)">
#                 -0.13
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(164,253,185)">
#                 0.01
#                 </td>
#
#                 <td style="background-color:rgb(224,163,140)">
#                 -0.67
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>Isotropic_22</td>
#
#                 <td style="background-color:rgb(175,237,177)">
#                 -0.13
#                 </td>
#
#                 <td style="background-color:rgb(164,253,185)">
#                 0.01
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(178,232,175)">
#                 -0.16
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>FermiDiffuse_22</td>
#
#                 <td style="background-color:rgb(182,225,172)">
#                 -0.21
#                 </td>
#
#                 <td style="background-color:rgb(224,163,140)">
#                 -0.67
#                 </td>
#
#                 <td style="background-color:rgb(178,232,175)">
#                 -0.16
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#             </tr>
#             </table>
#
#             <pre id="NJPConXgfs" style="display:none;">
#             <textarea rows="17" cols="50" onclick="this.select()" readonly>%\usepackage[table]{xcolor} % include this for color
# %\usepackage{rotating} % include this for rotate header
# %\documentclass[xcolor=table]{beamer} % for beamer
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# \rotatebox{90}{} & \rotatebox{90}{$Bubbles_{22}$} & \rotatebox{90}{$DM_{22}$} & \rotatebox{90}{$Isotropic_{22}$} & \rotatebox{90}{$FermiDiffuse_{22}$}\\
# \hline
# $Bubbles_{22}$ & \cellcolor[RGB]{255,117,117} 1.00 & \cellcolor[RGB]{175,237,177} -0.13 & \cellcolor[RGB]{175,237,177} -0.13 & \cellcolor[RGB]{182,225,172} -0.21\\
# \hline
# $DM_{22}$ & \cellcolor[RGB]{175,237,177} -0.13 & \cellcolor[RGB]{255,117,117} 1.00 & \cellcolor[RGB]{164,253,185} 0.01 & \cellcolor[RGB]{224,163,140} -0.67\\
# \hline
# $Isotropic_{22}$ & \cellcolor[RGB]{175,237,177} -0.13 & \cellcolor[RGB]{164,253,185} 0.01 & \cellcolor[RGB]{255,117,117} 1.00 & \cellcolor[RGB]{178,232,175} -0.16\\
# \hline
# $FermiDiffuse_{22}$ & \cellcolor[RGB]{182,225,172} -0.21 & \cellcolor[RGB]{224,163,140} -0.67 & \cellcolor[RGB]{178,232,175} -0.16 & \cellcolor[RGB]{255,117,117} 1.00\\
# \hline
# \end{tabular}</textarea>
#             </pre>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#HHfougncXD').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>PSC</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>Bubbles_23</td>
#                 <td>8.619751e-01</td>
#                 <td>1.302553e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>DM_23</td>
#                 <td>3.123927e+03</td>
#                 <td>1.570996e+02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>Isotropic_23</td>
#                 <td>1.395053e+00</td>
#                 <td>2.135964e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>FermiDiffuse_23</td>
#                 <td>1.000000e+00</td>
#                 <td>8.349996e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="HHfougncXD" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & PSC & 1.000e+00 & 0.000e+00 &  &  &  &  & FIXED\\
# \hline
# 2 & $Bubbles_{23}$ & 8.620e-01 & 1.303e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 3 & $DM_{23}$ & 3.124e+03 & 1.571e+02 &  &  &  &  & \\
# \hline
# 4 & $Isotropic_{23}$ & 1.395e+00 & 2.136e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# 5 & $FermiDiffuse_{23}$ & 1.000e+00 & 8.350e-01 &  &  & 0.000e+00 & 0.000e+00 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# WARNING: Fit for bin 23 is reported invalid

# %%
import cPickle as pickle

#pickle.dump(A, open('p6v11_Analysis.pickle','wb'))
#pickle.dump(A, open('p7v6_Analysis.pickle','wb'))

# %%
pickle.dump(A.loglike, open('p6v11_Analysis_loglike.pickle','wb'))
#pickle.dump(A.loglike, open('p7v6_Analysis_loglike.pickle','wb'))
