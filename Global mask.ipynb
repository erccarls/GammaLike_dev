# %%
import Analysis


A = Analysis.Analysis()

# %%
A.BinPhotons(infile='./binned_photons_P8R2_PSF3_CLEAN_V6_calore.npy')

# %%
import healpy
healpy.mollview(np.log10(np.sum(A.binned_data[3:],axis=0))*A.GenSquareMask(l_range=[-180.,180], b_range=[-90.,90.], plane_mask=8.),cbar=False, title='')
# plt.show()

healpy.mollview(np.log10(np.sum(A.binned_data[3:],axis=0))*A.GenSquareMask(l_range=[-80.,80], b_range=[-8.,8.], plane_mask=0.),cbar=False, title='')

A.GenSquareMask(l_range=[-180,-80], b_range=[-8.,8.], plane_mask=0)
A.GenSquareMask(l_range=[80,180], b_range=[-8.,8.], plane_mask=0, merge=True)

healpy.mollview(np.log10(np.sum(A.binned_data[3:],axis=0))*A.mask,cbar=False, title='')

# healpy.mollview(np.log10(np.sum(A.binned_data[3:],axis=0)*A.GenSquareMask(l_range=[80.,-80], b_range=[-8.,8.], plane_mask=0.)),cbar=False, title='')
# healpy.mollview(np.log10(np.sum(A.binned_data[3:],axis=0)*A.GenSquareMask(l_range=[-80.,80], b_range=[-8.,8.], plane_mask=0.)),cbar=False, title='')
# Out:
# /home/carlson/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: RuntimeWarning: divide by zero encountered in log10
#   from IPython.kernel.zmq import kernelapp as app
# /home/carlson/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: RuntimeWarning: invalid value encountered in multiply
#   from IPython.kernel.zmq import kernelapp as app
# /home/carlson/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: RuntimeWarning: divide by zero encountered in log10
# /home/carlson/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: RuntimeWarning: invalid value encountered in multiply
# /home/carlson/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:10: RuntimeWarning: divide by zero encountered in log10
# /home/carlson/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:10: RuntimeWarning: invalid value encountered in multiply

# %%
healpy.cartview(np.log10(np.sum(A.binned_data[3:],axis=0))*A.GenSquareMask(l_range=[-20,20],b_range=[-20,20], plane_mask=2),cbar=False, title='', latra=[-20,20], lonra=[-20,20] )
# Out:
# /home/carlson/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':
# /home/carlson/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: RuntimeWarning: invalid value encountered in multiply
#   if __name__ == '__main__':
