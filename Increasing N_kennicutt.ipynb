# %%
import healpy 

hdu_k = pyfits.open('./testing_temp/pi0_decay_healpix_54_mod_l_3.gz')
hdu_l = pyfits.open('./testing_temp/pi0_decay_healpix_54_mod_l_14.gz')

# %%
m = healpy.cartview(hdu_l[1].data.field(10)/hdu_k[1].data.field(10), return_projected_map=True, hold=True)
plt.clf()
plt.figure()
plt.imshow(m, origin='lower', cmap='bwr', vmin=.5, vmax=1.5)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f43b99f3ab8>

# %%
import h5py
h5py.
